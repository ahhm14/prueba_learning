# %%
#Analizar los datos y hacer gráficas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
filepath = r'C:\Users\alex1\Desktop\Personal\Cursos\Data Analyst Fundamentals\Proyecto Airbnb\listings.csv'

# %%
airbnb_data = pd.read_csv(filepath)

# %%
airbnb_data.head()
# Out:
#      id                                 name  host_id    host_name  \
# 0  2539   Clean & quiet apt home by the park     2787         John
# 1  2595                Skylit Midtown Castle     2845     Jennifer
# 2  3330   ++ Brooklyn Penthouse Guestroom ++     4177         Jbee
# 3  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 4  3831      Cozy Entire Floor of Brownstone     4869  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2            Brooklyn  Williamsburg  40.70856  -73.94236     Private room
# 3           Manhattan        Harlem  40.80902  -73.94190     Private room
# 4            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
airbnb_data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.974800e+04  4.974800e+04  49748.000000  49748.000000  49748.000000
# mean   1.738967e+07  6.058319e+07     40.729299    -73.953238    150.931796
# std    9.816381e+06  6.951425e+07      0.053860      0.044968    225.025933
# min    2.539000e+03  2.571000e+03     40.499790    -74.242850      0.000000
# 25%    9.004913e+06  7.426523e+06     40.690750    -73.983500     69.000000
# 50%    1.834661e+07  2.899476e+07     40.723670    -73.956450    107.000000
# 75%    2.609943e+07  9.698084e+07     40.763130    -73.937530    175.000000
# max    3.285890e+07  2.471184e+08     40.911690    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    49748.000000       49748.000000       39260.000000
# mean         7.064284          22.244894           1.300503
# std         20.481797          41.954729           1.563485
# ...

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49748 entries, 0 to 49747
# Data columns (total 16 columns):
# id                                49748 non-null int64
# name                              49731 non-null object
# host_id                           49748 non-null int64
# host_name                         49740 non-null object
# neighbourhood_group               49748 non-null object
# neighbourhood                     49748 non-null object
# latitude                          49748 non-null float64
# longitude                         49748 non-null float64
# room_type                         49748 non-null object
# price                             49748 non-null int64
# minimum_nights                    49748 non-null int64
# number_of_reviews                 49748 non-null int64
# last_review                       39260 non-null object
# reviews_per_month                 39260 non-null float64
# calculated_host_listings_count    49748 non-null int64
# ...

# %% [markdown]
# ## Maximum number of reviews

# %%
max_revs = airbnb_data.sort_values(by = ['number_of_reviews','price'], ascending= [False, False])

# %%
max_revs
# Out:
#              id                                               name    host_id  \
# 2178     903972                         Great Bedroom in Manhattan    4734398
# 12653   9145202                            Room near JFK Queen Bed   47621202
# 14538  10101135                            Room Near JFK Twin Beds   47621202
# 2017     834190           Manhattan Lux Loft.Like.Love.Lots.Look !    2369681
# 11417   8168619                  Steps away from Laguardia airport   37312959
# 127       26785                       Park Slope Green Guest House      42273
# 1335     546383                   My Little Guest Room in Flushing    2680820
# 5202    3474320                 Private brownstone studio Brooklyn   12949460
# 22264  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 8575    6157276                    Bright LARGE BED near Manhattan   23591164
# 244       58059                PRIVATE Room on Historic Sugar Hill     277379
# ...

# %%
airbnb_data.loc[2178, 'number_of_reviews']
# Out:
# 588

# %%
neighbourhood_list = list(airbnb_data.neighbourhood_group)
room_list_2 = list(airbnb_data.room_type)
price_list = list(airbnb_data.price)
nofreviews = list(airbnb_data.number_of_reviews)
availa_list = list(airbnb_data.availability_365)

# %%
neighbours = list()

# %%
for x in neighbourhood_list:
    if not x in neighbours:
        neighbours.append(x)
        
print(neighbours)
# Out:
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']

# %%
#airbnb_data['neighbourhood_group'].groupby(neighbours)

# %% [markdown]
# ## N° of Listing per Neighbourhood

# %%
type(neighbourhood_list[0])
# Out:
# str

# %%
my_dict = {i:neighbourhood_list.count(i) for i in neighbourhood_list}

# %%
my_dict
# Out:
# {'Brooklyn': 20312,
#  'Manhattan': 22559,
#  'Queens': 5525,
#  'Staten Island': 351,
#  'Bronx': 1001}

# %%
neighbours_1 = list(my_dict.keys())

# %%
neighbours_2 = list(my_dict.values())

# %%
plt.title('Listings per Neighbourhood in NYC')
plt.xlabel('Neighbour')
plt.ylabel('N° of Listings')
plt.bar(neighbours_1,neighbours_2)
plt.show()

# %%
#for k, rows in data.groupby('dom'):
#   print((k, rows))
#   break

def count_rows(rows):
    return len(rows)

by_neighbour = airbnb_data.groupby('neighbourhood_group').apply(count_rows)
by_neighbour
# Out:
# neighbourhood_group
# Bronx             1001
# Brooklyn         20312
# Manhattan        22559
# Queens            5525
# Staten Island      351
# dtype: int64

# %%
by_neighbour_2 = airbnb_data.groupby('neighbourhood').apply(count_rows)

# %%
import statistics

# %%
max_price = {i:max(airbnb_data.price) for i in neighbourhood_list}
min_price = {i:min(airbnb_data.price) for i in neighbourhood_list}
#avg_price = {i:(airbnb_data.price) for i in neighbourhood_list}

# %%
max_price
# Out:
# {'Brooklyn': 10000,
#  'Manhattan': 10000,
#  'Queens': 10000,
#  'Staten Island': 10000,
#  'Bronx': 10000}

# %%
from collections import Counter
rooms_dict = Counter(airbnb_data.room_type)
rooms_dict
# Out:
# Counter({'Private room': 22578, 'Entire home/apt': 26061, 'Shared room': 1109})

# %%
def separate_lists(dict):
    list_1 = list(dict.keys())
    list_2 = list(dict.values())
    total = sum(list_2)
    print(list_1, list_2, total)
    plt.title('Listings per type of room in NYC')
    plt.xlabel('Type of Room')
    plt.ylabel('N° of Listings')
    plt.bar(list_1,list_2)
    plt.show()

# %%
separate_lists(rooms_dict)
#xlist = list_1
#list = list_2
# Out:
# ['Private room', 'Entire home/apt', 'Shared room'] [22578, 26061, 1109] 49748

# %%
plt.bar(types_of_room, manht_list, color = "teal", label ='Manhattan')
plt.bar(types_of_room, brooklyn_list, label = 'Brooklyn', color='coral')
plt.bar(types_of_room, queens_list, label = 'Queens')
plt.bar(types_of_room, staten_list, color = 'y', label = 'Staten Island')
plt.bar(types_of_room, bronx_list, label = 'Bronx', color='lime')
plt.legend()
plt.title('Type of Room per Neighbourhood')
plt.ylabel('N° of Listings')
plt.xlabel('Type of Room')
plt.tight_layout()
plt.show()

# %%
airbnb_data.groupby('room_type').count()
# Out:
#                     id   name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt  26061  26055    26061      26057                26061
# Private room     22578  22568    22578      22574                22578
# Shared room       1109   1108     1109       1109                 1109
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt          26061     26061      26061  26061           26061
# Private room             22578     22578      22578  22578           22578
# Shared room               1109      1109       1109   1109            1109
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt              26061        20915              20915
# Private room                 22578        17544              17544
# Shared room                   1109          801                801
#
#                  calculated_host_listings_count  availability_365
# ...

# %%
neighbour_room = list(zip(neighbourhood_list,room_list_2))
neighbour_room_pd = pd.DataFrame(neighbour_room, columns = ['Neighbourhood', 'Type of Room'])
neighbour_room_pd.head()
# Out:
#   Neighbourhood     Type of Room
# 0      Brooklyn     Private room
# 1     Manhattan  Entire home/apt
# 2      Brooklyn     Private room
# 3     Manhattan     Private room
# 4      Brooklyn  Entire home/apt

# %%
#CONTADOR DE TIPOS DE CUARTOS POR VECINDARIO 
'''
count = 0
Sta_Isl_room = []
for x in neighbour_room:
        if x.index(0) == 'Brooklyn'
        print ('hola')
'''
#print(Sta_Isl_room)

# %% [markdown]
# # Reviews per Type of Room

# %%
#We want to know how many reviews for each type of room. 
airbnb_data.head(5)
privcont = 0
entcont = 0
conshare = 0
for x in airbnb_data.room_type:
    if x == 'Private room':
        privcont = airbnb_data.number_of_reviews + privcont
    if x == 'Entire home/apt':
        entcont = airbnb_data.number_of_reviews + entcont
    if x == 'Shared room':
        conshare = airbnb_data.number_of_reviews + conshare
print (privcont, entcont, conshare)

# %% [markdown]
# ### Mapeo de la ubicación de las propiedades

# %%
plt.figure(figsize=(20, 20))
plt.plot(airbnb_data['longitude'], airbnb_data['latitude'], '.', ms = 0.3, alpha = 0.5)
plt.xlim(-74.2, -73.6)
plt.ylim(40.65, 40.9)
plt.show()

# %% [markdown]
# ### Relación Precio con Reviews

# %%
room_price = list(zip(nofreviews,price_list))

# %%
plt.title('Correlation N° reviews vs price')
plt.ylabel('Price')
plt.xlabel('N° of Reviews')
plt.ylim(40,800)
plt.xlim(0,600)
plt.scatter(nofreviews, price_list, marker = "o")
#plt.figure(figsze= (30,10))
plt.show()

# %%
#That property that is very expensive have many many reviews. By far the most expensive one

# %% [markdown]
# ## Checking on the availability

# %%
airbnb_data.head()

# %%
plt.ylim(0, 5000)
plt.scatter(availa_list, price_list, color='b')
plt.title('Availability vs Price')
plt.xlabel('365 days of the year ahead')
plt.ylabel('price')
plt.show()

# %%
plt.hist(price_list, bins=[50, 100, 150, 200, 250, 300, 350, 400, 450, 500], color='y')
plt.title('Most Common prices of airbnb rooms in New York City')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## END

# %%
def separate_cities(list1):
    list_manhattan = []
    count = 0
    for x in list1:
        if 'Brooklyn' is in x:
            print() #me falta poner el index para poder separar por ciudades
        count = count +1
        if count == 4:
            break

# %%
separate_cities(neighbour_room)

# %%
#Filtering data in pandas
manthattan_pd = airbnb_data[airbnb_data['neighbourhood_group'] == 'Manhattan']

# %%
manht_list = list(manthattan_pd.groupby('room_type').count().id)

# %%
manht_list

# %%
types_of_room = ['Private Room', 'Entire Home', 'Shared Room']

# %%
brooklyn_pd = airbnb_data[airbnb_data['neighbourhood_group'] == 'Brooklyn']
brooklyn_list = list(brooklyn_pd.groupby('room_type').count().id)

# %%
queens_pd = airbnb_data[airbnb_data['neighbourhood_group'] == 'Queens']
queens_list = list(queens_pd.groupby('room_type').count().id)

# %%
staten_pd = airbnb_data[airbnb_data['neighbourhood_group'] == 'Staten Island']
staten_list= list(staten_pd.groupby('room_type').count().id)

# %%
bronx_pd = airbnb_data[airbnb_data['neighbourhood_group'] == 'Bronx']
bronx_list= list(bronx_pd.groupby('room_type').count().id)
